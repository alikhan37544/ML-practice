# %%
## import the libraries 
import matplotlib.pyplot as plt 
import pandas as pd 
from random import choice

# %%
exp=[]
sal=[]
for i in range(21,60):
    exp.append(i+choice([1.1,2.2,-3.3,0.2]))
    sal.append(29.9*i-0.35+choice([2.2,-3.2,4.3,1.1]))
df=pd.DataFrame(list(zip(exp,sal)),columns="exp sal".split())
df
# Out:
#      exp      sal
# 0   21.2   631.85
# 1   24.2   654.25
# 2   23.2   689.55
# 3   25.1   721.55
# 4   21.7   748.25
# 5   22.7   781.35
# 6   23.7   811.25
# 7   29.1   839.05
# 8   29.2   867.85
# 9   31.1   900.95
# 10  31.2   930.85
# 11  34.2   953.25
# 12  35.2   988.55
# 13  36.2  1020.55
# 14  37.2  1048.35
# 15  37.1  1078.25
# 16  37.2  1107.05
# 17  34.7  1132.65
# 18  35.7  1166.85
# 19  40.2  1199.95
# 20  43.2  1227.75
# 21  44.2  1257.65
# 22  39.7  1282.15
# 23  46.2  1316.35
# 24  41.7  1347.35
# 25  46.2  1371.85
# 26  48.1  1409.25
# 27  49.1  1437.05
# 28  49.2  1461.55
# 29  46.7  1498.95
# 30  52.1  1525.65
# 31  52.2  1555.55
# 32  55.2  1585.45
# 33  50.7  1615.35
# 34  51.7  1645.25
# 35  52.7  1678.35
# 36  53.7  1706.15
# 37  59.1  1730.65
# 38  60.1  1760.55

# %%
# visualising the dataset 

plt.scatter(exp,sal)
plt.show()
plt.plot(exp,sal)
plt.show()

# %%
X=df.iloc[:,:-1].values
Y=df.iloc[:,-1].values
Y.shape
# Out:
# (39,)

# %%
Y
# Out:
# array([ 631.85,  654.25,  689.55,  721.55,  748.25,  781.35,  811.25,
#         839.05,  867.85,  900.95,  930.85,  953.25,  988.55, 1020.55,
#        1048.35, 1078.25, 1107.05, 1132.65, 1166.85, 1199.95, 1227.75,
#        1257.65, 1282.15, 1316.35, 1347.35, 1371.85, 1409.25, 1437.05,
#        1461.55, 1498.95, 1525.65, 1555.55, 1585.45, 1615.35, 1645.25,
#        1678.35, 1706.15, 1730.65, 1760.55])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.20,random_state=0)
print(x_test,y_test)
# Out:
# [[21.7]
#  [49.2]
#  [46.7]
#  [50.7]
#  [51.7]
#  [46.2]
#  [31.2]
#  [39.7]] [ 748.25 1461.55 1498.95 1615.35 1645.25 1371.85  930.85 1282.15]

# %%
from sklearn.linear_model import LinearRegression

# Creating an object of the class Linear Regression
model= LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred,y_test
# Out:
# (array([ 653.36481862, 1458.76025697, 1385.54248984, 1502.69091724,
#         1531.97802409, 1370.89893642,  931.59233368, 1180.5327419 ]),
#  array([ 748.25, 1461.55, 1498.95, 1615.35, 1645.25, 1371.85,  930.85,
#         1282.15]))

# %%
## Visualising the linear Regression model with Y_train and Prediction
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,model.predict(x_train),color="blue")
plt.title("Training Comparision")
plt.xlabel("Expereince")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,model.predict(x_test),color="blue")
plt.title("Test Set Comparision")
plt.xlabel("Expereince")
plt.ylabel("Salary")
plt.show()

# %%
# Root mean square error find



from sklearn.metrics import mean_squared_error


err = mean_squared_error(y_test, y_pred)

print(err)

import numpy as np
x = np.sqrt(err)
print(x)
# Out:
# 7215.296981512318
# 84.94290424462963
